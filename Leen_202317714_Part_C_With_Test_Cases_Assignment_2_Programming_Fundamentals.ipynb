# %%
#Leen 202317714 code

#defining a class named "Guest"

class Guest:

    """This class represents a guest at the Royal Stay Hotel"""

    #intializing the attributes for the guest class (private)

    def __init__(self, guest_name, guest_email, guest_contact_number, guest_id, guest_loyalty_status):
        self.__guest_name = guest_name
        self.__guest_email = guest_email
        self.__guest_contact_number = guest_contact_number
        self.__guest_id = guest_id
        self.__guest_loyalty_status = guest_loyalty_status

#defining the get methods for each of the appropriate attributes for the Guest class

    def get_guest_name(self):
        return self.__guest_name

    def get_guest_email(self):
        return self.__guest_email

    def get_guest_contact_number(self):
        return self.__guest_contact_number

    def get_guest_id(self):
        return self.__guest_id

    def get_guest_loyalty_status(self):
        return self.__guest_loyalty_status

#defining the set methods for each of the appropriate attributes for the Guest class

    def set_guest_name(self, name):
        self.__guest_name = name

    def set_guest_email(self, email):
        self.__guest_email = email

    def set_guest_contact_number(self, contact):
        self.__guest_contact_number = contact

    def set_guest_loyalty_status(self, status):
        self.__guest_loyalty_status = status

#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output


    def guest_create_account(self):
        return f"The guest account for {self.__guest_name} has been created. Thank you!"

    def update_guest_profile(self):
        return f"The guest profile for guest ID: {self.__guest_id} has been successfully updated."

    def view_guest_reservation_history(self):
        return f"Currently displaying reservation history for guest with ID: {self.__guest_id}."

    def __str__(self):
        return f"Guest ID: {self.__guest_id} | Guest name: {self.__guest_name} | Guest email: {self.__guest_email} | Guest contact: {self.__guest_contact_number} | Guest loyalty status: {self.__guest_loyalty_status}"


#defining a class named "Booking"

class Booking:

    """This class represents a booking that is to be made by a guest"""

    #intializing the attributes for the booking class (private)

    def __init__(self, guest_id, room_number, room_booking_id, booking_status, check_in_date, check_out_date):
        self.__guest_id = guest_id
        self.__room_number = room_number
        self.__room_booking_id = room_booking_id
        self.__booking_status = booking_status
        self.__check_in_date = check_in_date
        self.__check_out_date = check_out_date


#defining the get methods for each of the appropriate attributes for the Booking class


    def get_guest_id(self):
        return self.__guest_id

    def get_room_number(self):
        return self.__room_number

    def get_room_booking_id(self):
        return self.__room_booking_id

    def get_booking_status(self):
        return self.__booking_status

    def get_check_in_date(self):
        return self.__check_in_date

    def get_check_out_date(self):
        return self.__check_out_date


#defining the set methods for each of the appropriate attributes for the Booking class

    def set_booking_status(self, status):
        self.__booking_status = status


#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output

    def search_available_rooms(self):
        return "Currently searching for rooms that are available..."

    def make_room_reservation(self):
        return f"Booking for guest with ID: {self.__guest_id} in room {self.__room_number} has been successfully made."

    def send_room_booking_confirmation(self):
        return f"Booking confirmation has been sent to guest owners of room: {self.__room_number} via Email."

    def cancel_reservation(self):
        self.set_booking_status("Cancelled")
        return f"Booking with ID: {self.__room_booking_id} has been successfully cancelled."

    def __str__(self):
        return f"Booking ID: {self.__room_booking_id} | Guest ID: {self.__guest_id} | Guest room: {self.__room_number} | Booking status: {self.__booking_status} | Guest check-in: {self.__check_in_date} | Guest check-out: {self.__check_out_date}"


#defining a class named "Room"

class Room:

    """This class represents a room in the Royal Stay Hotel"""

    #intializing the attributes for the guest class (private)

    def __init__(self, room_number, room_type, room_amenities, price_per_night, is_room_available):
        self.__room_number = room_number
        self.__room_type = room_type
        self.__room_amenities = room_amenities
        self.__price_per_night = price_per_night
        self.__is_room_available = is_room_available

#defining the get methods for each of the appropriate attributes for the Room class

    def get_room_number(self):
        return self.__room_number

    def get_room_type(self):
        return self.__room_type

    def get_room_amenities(self):
        return self.__room_amenities

    def get_price_per_night(self):
        return self.__price_per_night

    def get_is_room_available(self):
        return self.__is_room_available


#defining the set methods for each of the appropriate attributes for the Room class

    def set_room_type(self, room_type):
        self.__room_type = room_type

    def set_room_amenities(self, amenities):
        self.__room_amenities = amenities

    def set_price_per_night(self, price):
        self.__price_per_night = price

    def set_is_room_available(self, status):
        self.__is_room_available = status


#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output

    def display_rooms_available(self):
        if self.__is_room_available:
            return f"Room with number: {self.__room_number} is available."
        else:
            return f"Room with number: {self.__room_number} is not available."

    def update_room_availability(self, status):
        self.__is_room_available = status

    def __str__(self):
        return f"Room number: {self.__room_number} | Room type: {self.__room_type} | Room price: {self.__price_per_night} | Room availability: {self.__is_room_available}"


#defining a class named "Invoice"

class Invoice:

    """This class represents an invoice generated for a booking."""

    #intializing the attributes for the guest class (private)

    def __init__(self, invoice_id, room_booking_id, nightly_rate, additional_charges, discount_amount, promotion_applied, total_amount):
        self.__invoice_id = invoice_id
        self.__room_booking_id = room_booking_id
        self.__nightly_rate = nightly_rate
        self.__additional_charges = additional_charges
        self.__discount_amount = discount_amount
        self.__promotion_applied = promotion_applied
        self.__total_amount = total_amount

#defining the get methods for each of the appropriate attributes for the Invoice class

    def get_invoice_id(self):
        return self.__invoice_id

    def get_room_booking_id(self):
        return self.__room_booking_id

    def get_nightly_rate(self):
        return self.__nightly_rate

    def get_additional_charges(self):
        return self.__additional_charges

    def get_discount_amount(self):
        return self.__discount_amount

    def get_promotion_applied(self):
        return self.__promotion_applied

    def get_total_amount(self):
        return self.__total_amount

#defining the set methods for each of the appropriate attributes for the Invoice class

    def set_additional_charges(self, charges):
        self.__additional_charges = charges

    def set_discount_amount(self, discount):
        self.__discount_amount = discount

    def set_promotion_applied(self, promo):
        self.__promotion_applied = promo

    def set_total_amount(self, total):
        self.__total_amount = total



#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output


    def generate_the_invoice(self):
        return f"Invoice with ID: {self.__invoice_id} has been successfully generated."

    def print_the_invoice(self):
        return f"Currently printing the invoice for booking with ID: {self.__room_booking_id}."

    def __str__(self):
        return f"Invoice ID: {self.__invoice_id} | Booking ID: {self.__room_booking_id} | Nightly rate: {self.__nightly_rate} | Additional charges: {self.__additional_charges} | Discount amount: {self.__discount_amount} | Promotion applied: {self.__promotion_applied} | Total amount: {self.__total_amount}"



#defining a class named "Payment"

class Payment:

    """This class represents a payment made for an invoice"""

    #intializing the attributes for the guest class (private)

    def __init__(self, invoice_id, payment_id, payment_method, payment_total_amount, payment_status):
        self.__invoice_id = invoice_id
        self.__payment_id = payment_id
        self.__payment_method = payment_method
        self.__payment_total_amount = payment_total_amount
        self.__payment_status = payment_status

#defining the get methods for each of the appropriate attributes for the Payment class

    def get_invoice_id(self):
        return self.__invoice_id

    def get_payment_id(self):
        return self.__payment_id

    def get_payment_method(self):
        return self.__payment_method

    def get_payment_total_amount(self):
        return self.__payment_total_amount

    def get_payment_status(self):
        return self.__payment_status

#defining the set methods for each of the appropriate attributes for the Payment class

    def set_payment_status(self, status):
        self.__payment_status = status

#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output

    def check_the_payment_status(self):
        return f"Payment status for payment with ID {self.__payment_id} is {self.__payment_status}."

    def process_the_payment(self):
        return f"Currently processing payment with ID {self.__payment_id} using {self.__payment_method}."

    def __str__(self):
        return f"Payment ID: {self.__payment_id} | Invoice ID: {self.__invoice_id} | Total payment amount: {self.__payment_total_amount} | Payment status: {self.__payment_status}"



#defining a class named "LoyaltyProgram"

class LoyaltyProgram:

    """This class represents a guest's loyalty program information"""

    #intializing the attributes for the guest class (private)

    def __init__(self, guest_id, guest_loyalty_points, loyalty_reward_status):
        self.__guest_id = guest_id
        self.__guest_loyalty_points = guest_loyalty_points
        self.__loyalty_reward_status = loyalty_reward_status

#defining the get methods for each of the appropriate attributes for the LoyaltyProgram class

    def get_guest_id(self):
        return self.__guest_id

    def get_guest_loyalty_points(self):
        return self.__guest_loyalty_points

    def get_loyalty_reward_status(self):
        return self.__loyalty_reward_status

#defining the set methods for each of the appropriate attributes for the LoyaltyProgram class

    def set_guest_loyalty_points(self, points):
        self.__guest_loyalty_points = points

    def set_loyalty_reward_status(self, status):
        self.__loyalty_reward_status = status



#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output

    def check_loyalty_points_and_rewards(self):
        return f"Guest {self.__guest_id} has {self.__guest_loyalty_points} points."

    def redeem_loyalty_rewards(self):
        return f"Currently redeeming loyalty rewards for guest {self.__guest_id}."

    def add_loyalty_points(self):
        return f"Loyalty points have been successfully added for guest with ID: {self.__guest_id}."

    def __str__(self):
        return f"Guest ID: {self.__guest_id} | Guest loyalty points: {self.__guest_loyalty_points} | Reward status: {self.__loyalty_reward_status}"




#defining a class named "GuestServiceRequest"

class GuestServiceRequest:

    """This class represents a service request made by a guest"""

    #intializing the attributes for the guest class (private)

    def __init__(self, guest_id, guest_request_id, guest_request_status, guest_request_type):
        self.__guest_id = guest_id
        self.__guest_request_id = guest_request_id
        self.__guest_request_status = guest_request_status
        self.__guest_request_type = guest_request_type

#defining the get methods for each of the appropriate attributes for the GuestServiceRequest class

    def get_guest_id(self):
        return self.__guest_id

    def get_guest_request_id(self):
        return self.__guest_request_id

    def get_guest_request_status(self):
        return self.__guest_request_status

    def get_guest_request_type(self):
        return self.__guest_request_type

#defining the set methods for each of the appropriate attributes for the GuestServiceRequest class

    def set_guest_request_status(self, status):
        self.__guest_request_status = status


#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output

    def send_guest_service_request(self):
        return f"Request with ID: {self.__guest_request_id} has been sent by guest with ID: {self.__guest_id}."

    def notify_hotel_staff_about_request(self):
        return f"Hotel staff have been successfully notified for request with ID: {self.__guest_request_id}."

    def __str__(self):
        return f"Request ID: {self.__guest_request_id} | Guest ID: {self.__guest_id} | Request type: {self.__guest_request_type} | Guest request status: {self.__guest_request_status}"






#defining a class named "Feedback"

class Feedback:

    """This class represents feedback provided by a guest"""

    #intializing the attributes for the guest class (private)

    def __init__(self, guest_id, feedback_id, feedback_comment, feedback_hotel_rating):
        self.__guest_id = guest_id
        self.__feedback_id = feedback_id
        self.__feedback_comment = feedback_comment
        self.__feedback_hotel_rating = feedback_hotel_rating

#defining the get methods for each of the appropriate attributes for the Feedback class

    def get_guest_id(self):
        return self.__guest_id

    def get_feedback_id(self):
        return self.__feedback_id

    def get_feedback_comment(self):
        return self.__feedback_comment

    def get_feedback_hotel_rating(self):
        return self.__feedback_hotel_rating

#defining the set methods for each of the appropriate attributes for the Feedback class

    def set_feedback_comment(self, comment):
        self.__feedback_comment = comment

    def set_feedback_hotel_rating(self, rating):
        self.__feedback_hotel_rating = rating


#defining the methods the user (guest) is able to use/can perform within the system
#we also define a string representation of the class to organize it in a neat way when it has been printed in the output


    def submit_guest_feedback(self):
        return f"Feedback has been submitted by guest with ID: {self.__guest_id}."

    def __str__(self):
        return f"Feedback ID: {self.__feedback_id} | Guest ID: {self.__guest_id} | Guest rating: {self.__feedback_hotel_rating} | Guest comment: {self.__feedback_comment}"



#PART C - Test  case 1: Guest Account Creation with 2 examples

guest1 = Guest("Shamma Khalifa", "shamma@gmail.com", "0501234567", "G001", "Gold")
guest2 = Guest("Saif Ahmed", "saif@gmail.com", "0508910111", "G002", "Silver")

print(guest1.guest_create_account())
print(guest2.guest_create_account())

print(guest1)
print(guest2)

print("Guest 1's Email address is:", guest1.get_guest_email())
print("Guest 2's Loyalty Status is:", guest2.get_guest_loyalty_status())

print("\n-----------------------------------------\n")

#PART C - Test Case 2: Searching for Available Rooms with 2 examples

print("Searching for rooms that are available for the guests...")

room1 = Room("201", "Single Room", ["Snacks", "WiFi", "Towels", "Room service", "Shampoos", "TV"], 400, True)
room2 = Room("202", "Double Room", ["WiFi", "Coffee machine", "Hair dryer", "Slippers", "Mini-bar"], 500, False)

print(room1.display_rooms_available())
print(room2.display_rooms_available())

print("\n-----------------------------------------\n")

#PART C - Test Case 3: Making a Room Reservation with 2 examples

booking1 = Booking("G001", "201", "B001", "Confirmed", "2025-03-29", "2025-04-09")
booking2 = Booking("G002", "202", "B002", "Confirmed", "2025-10-10", "2025-10-20")

print(booking1.make_room_reservation())
print(booking2.make_room_reservation())

print(booking1)
print(booking2)

print(booking1.send_room_booking_confirmation())
print(booking2.send_room_booking_confirmation())

print("\n-----------------------------------------\n")

#PART C - Test Case 4: Booking Confirmation Notification with 2 examples

booking1 = Booking("G001", "230", "B001", "Confirmed", "2025-07-14", "2025-07-18")
booking2 = Booking("G002", "222", "B002", "Confirmed", "2025-09-03", "2025-09-05")

print(booking1.send_room_booking_confirmation())
print(booking2.send_room_booking_confirmation())

print("\n-----------------------------------------\n")

#PART C - Test Case 5: Invoice Generation for a Booking with 2 examples

invoice1 = Invoice("INVOICE001", "B001", 400.0, 55.0, 25.0, "Day In The Summer Promotion", 430.0)
invoice2 = Invoice("INVOICE002", "B002", 500.0, 43.0, 15.0, "Hotel Loyalty Discount", 528.0)

print(invoice1.generate_the_invoice())
print(invoice2.generate_the_invoice())

print(invoice1.print_the_invoice())
print(invoice2.print_the_invoice())

print("Total amount for Invoice 1 is:", invoice1.get_total_amount())
print("Promotion that got applied for Invoice 2 is:", invoice2.get_promotion_applied())

print("\n----------------------------------------\n")

#PART C - Test Case 6: Processing Different Payment Methods with 2 examples

payment1 = Payment("INVOICE001", "PAYMENT001", "Credit Card", 430.0, "Completed")
payment2 = Payment("INVOICE002", "PAYMENT002", "Mobile Wallet", 528.0, "Completed")

print(payment1.process_the_payment())
print(payment2.process_the_payment())

print(payment1.check_the_payment_status())
print(payment2.check_the_payment_status())

print(payment1)
print(payment2)

print("\n------------------------------------------\n")

#PART C - Test case 7: Cancellation of a Reservation with 2 examples

bookingcancellation1 = Booking("G001", "230", "B001", "Confirmed", "2025-07-14", "2025-07-18")
bookingcancellation2 = Booking("G002", "222", "B002", "Confirmed", "2025-09-03", "2025-09-05")

print("The status of Booking 1 before being cancelled:", bookingcancellation1.get_booking_status())
print("The status of Booking 2 before being cancelled:", bookingcancellation2.get_booking_status())

print(bookingcancellation1.cancel_reservation())
print(bookingcancellation2.cancel_reservation())

print("The status of Booking 1 after being cancelled:", bookingcancellation1.get_booking_status())
print("The status of Booking 2 after being cancelled:", bookingcancellation2.get_booking_status())

print("\n----------------------------------------\n")
# Out:
# The guest account for Shamma Khalifa has been created. Thank you!
# The guest account for Saif Ahmed has been created. Thank you!
# Guest ID: G001 | Guest name: Shamma Khalifa | Guest email: shamma@gmail.com | Guest contact: 0501234567 | Guest loyalty status: Gold
# Guest ID: G002 | Guest name: Saif Ahmed | Guest email: saif@gmail.com | Guest contact: 0508910111 | Guest loyalty status: Silver
# Guest 1's Email address is: shamma@gmail.com
# Guest 2's Loyalty Status is: Silver
#
# -----------------------------------------
#
# Searching for rooms that are available for the guests...
# Room with number: 201 is available.
# Room with number: 202 is not available.
#
# -----------------------------------------
#
# Booking for guest with ID: G001 in room 201 has been successfully made.
# Booking for guest with ID: G002 in room 202 has been successfully made.
# ...
